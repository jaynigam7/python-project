# %% [markdown]
# ## Day-2 for Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Using CSV file for data

# %%
df=pd.read_csv("prac.csv")
df
# Out:
#     ID            Name  Age  Gender   Department  Salary  Experience  \
# 0    1     Aarav Mehta   25    Male  Engineering   52000           2
# 1    2     Isha Sharma   28  Female    Marketing   48000           3
# 2    3     Rahul Verma   35    Male      Finance   75000           8
# 3    4      Neha Singh   30  Female           HR   60000           5
# 4    5     Karan Patel   26    Male  Engineering   55000           2
# 5    6      Priya Nair   33  Female       Design   67000           7
# 6    7    Ankit Tiwari   24    Male  Engineering   50000           1
# 7    8      Ritika Das   27  Female      Finance   62000           4
# 8    9    Manish Gupta   40    Male   Management   95000          12
# 9   10     Simran Kaur   29  Female    Marketing   53000           3
# 10  11     Vikas Yadav   32    Male  Engineering   72000           6
# 11  12      Anjali Rao   31  Female           HR   61000           5
# 12  13    Saurabh Jain   27    Male      Finance   59000           3
# ...

# %% [markdown]
# ### Data handling and cleaning

# %%
null=df.isnull()
null
# Out:
#        ID   Name    Age  Gender  Department  Salary  Experience   City  \
# 0   False  False  False   False       False   False       False  False
# 1   False  False  False   False       False   False       False  False
# 2   False  False  False   False       False   False       False  False
# 3   False  False  False   False       False   False       False  False
# 4   False  False  False   False       False   False       False  False
# 5   False  False  False   False       False   False       False  False
# 6   False  False  False   False       False   False       False  False
# 7   False  False  False   False       False   False       False  False
# 8   False  False  False   False       False   False       False  False
# 9   False  False  False   False       False   False       False  False
# 10  False  False  False   False       False   False       False  False
# 11  False  False  False   False       False   False       False  False
# ...

# %%
res=null.sum()
res
# Out:
# ID              0
# Name            0
# Age             0
# Gender          0
# Department      0
# Salary          0
# Experience      0
# City            0
# Joining_Date    0
# dtype: int64
