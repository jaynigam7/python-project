# %% [markdown]
# # Beginner
# 1. Print "Hello, Data Engineer!".
# 2. Take two numbers as input and print their sum.
# 3. Find whether a number is even or odd.
# 4. Find the largest of three numbers.
# 5. Reverse a string without using reversed().
# 6. Count the number of vowels in a string.
# 7. Check whether a string is a palindrome.
# 8. Find the factorial of a number.
# 9. Generate the Fibonacci series up to n terms.
# 10. Find the largest element in a list.

# %%
# print("Hello, Data Engineer!")
# a=int(input("Enter a(number): "))
# b=int(input("Enter b(number): "))
# c=int(input("Enter c(number): "))
# c=a+b
# print("The sum of a and b is:", c)
# x=lambda a,b: a+b
# print(x(5,6))
# if a%2==0:
#     print("The number is even")
# else:
#     print("The number is odd")
# x=lambda a: "Even" if a%2==0 else "Odd"
# print(x(a))
# if a>b and a>c:
#     print(f"{a} is the largest number")
# elif b>a and b>c:
#     print(f"{b} is the largest number")
# else:
#     print(f"{c} is the largest number")
# a = "Hello World"
# print(a[::-1])
# text = "Hello World"
# vowels = "aeiouAEIOU"
# vowel_count = sum(1 for char in text if char in vowels)
# print(f"The number of vowels in '{text}' is: {vowel_count}")
# a=input("Enter a string: ")
# if a==a[::-1]:
#     print("The string is a palindrome")
# else:
#     print("The string is not a palindrome")
# a = int(input("Enter a number: "))
# def fac(n):
#     if n == 0 or n == 1:
#         return 1
#     elif n < 0:
#         return "Factorial Error please give value above or equal then 0"
#     else:
#         return n * fac(n - 1)
# result = fac(a)
# print(f"The factorial of {a} is: {result}")
# a = int(input("Enter a number: "))
# def fib(n):
#     if n <= 0:
#         return []
#     elif n == 1:
#         return [0]
#     elif n == 2:
#         return [0, 1]
#     else:
#         fib_sequence = [0, 1]
#         for i in range(2, n):
#             next_number = fib_sequence[i - 1] + fib_sequence[i - 2]
#             fib_sequence.append(next_number)
#         return fib_sequence

# result = fib(a)
# print(f"The Fibonacci sequence up to {a} terms is: {result}")
numbers = list(map(int, input("Enter numbers separated by spaces: ").split()))
print(f"The greatest number in {numbers} is : {max(numbers)}")
# Out:
# The greatest number in [45, 23, 13, 68, 9, 532, 678, 90987] is : 90987

# %% [markdown]
# # Intermediate
