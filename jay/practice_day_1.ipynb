# %% [markdown]
# # Day-1

# %%
user = int(input("Enter your number: ")) #3
if user % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")
# Out:
# The number is odd.

# %%
a=int(input("Enter the A number:")) #4
b=int(input("Enter the B number:")) #3
c=int(input("Enter the C number:")) #5
if a>b and a>c:
    print("A is the greatest number")
elif b>a and b>c:
    print("B is the greatest number")
else:
    print("C is the greatest number")
# Out:
# C is the greatest number

# %%
num = int(input("Enter the number to find factorial: ")) #70

factorial = 1 
i = 1 

while i <= num: 
    factorial = factorial * i
    i += 1

print("The factorial is:", factorial)
# Out:
# The factorial is: 11978571669969891796072783721689098736458938142546425857555362864628009582789845319680000000000000000

# %%
import math
n=int(input("Enter a number to check if it is prime: "))

for i in range(2, int(math.sqrt(n)) + 1):
        if n % i == 0:
            print(n, "is not a prime number")
        else:
            print(n, "is a prime number")
# Out:
# 4 is not a prime number

# %%
from turtle import *
from colorsys import *

bgcolor("black")
tracer(0)
pensize(2)

h = 0

for i in range(360):
    h += 0.003
    r, g, b = hsv_to_rgb(h, 1, 1)     # glowing neon color
    color(r, g, b)

    up()
    goto(0, 0)
    down()

    # inner glowing swirl
    circle(i/3, 60)
    left(20)

    # outer shining petals
    for j in range(5):
        circle(150 - i/5, 60)
        right(120)

    right(7)          # rotation for 3D effect
    pensize(1 + i/150)  # glowing thickness

    update()          # smooth animation

done()
